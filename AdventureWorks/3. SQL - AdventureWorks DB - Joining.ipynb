# %%
import pyodbc

# defining the server and the database
server = '(localdb)\mssqllocaldb' 
database = 'AdventureWorks2012'  

# Define the connection string
conn = pyodbc.connect(
    'DRIVER={ODBC Driver 17 for SQL Server}; \
    SERVER='+ server +'; \
    DATABASE ='+ database +';\
    Trusted_Connection=yes;'
)

# %%
# Question 1 - AdventureWorks DB - ProductListPriceHistory & Product table
# 1. Get product name, end date, and list price
# (join product and ProductListPriceHistory tables on ProductID)

# SELECT Product.Name, PriceHistory.EndDate, and PriceHistory.ListPrice
# JOIN Product and ProductListPriceHistory
# ON ProductID
# [AdventureWorks2012].[Production].[Product] AS Product
# [AdventureWorks2012].[Production].[ProductListPriceHistory] AS PriceHistory

# Create the Cursor.
cursor = conn.cursor()

# Performing a join to combine ProductListPriceHistory & Product table
cursor.execute("""SELECT Product.Name, PriceHistory.EndDate, PriceHistory.ListPrice 
                  FROM [AdventureWorks2012].[Production].[Product] AS Product
                  JOIN [AdventureWorks2012].[Production].[ProductListPriceHistory] AS PriceHistory
                  ON Product.ProductID = PriceHistory.ProductID
                  ORDER BY Product.Name, PriceHistory.EndDate""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['Name', 'EndDate', 'ListPrice']
# ('All-Purpose Bike Stand', None, Decimal('159.0000'))
# ('AWC Logo Cap', None, Decimal('8.9900'))
# ('AWC Logo Cap', datetime.datetime(2006, 6, 30, 0, 0), Decimal('8.6442'))
# ('AWC Logo Cap', datetime.datetime(2007, 6, 30, 0, 0), Decimal('8.6442'))
# ('Bike Wash - Dissolver', None, Decimal('7.9500'))
# ('Cable Lock', datetime.datetime(2007, 6, 30, 0, 0), Decimal('25.0000'))
# ('Chain', None, Decimal('20.2400'))
# ('Classic Vest, L', None, Decimal('63.5000'))
# ('Classic Vest, M', None, Decimal('63.5000'))
# ('Classic Vest, S', None, Decimal('63.5000'))
# ('Fender Set - Mountain', None, Decimal('21.9800'))
# ('Front Brakes', None, Decimal('106.5000'))
# ('Front Derailleur', None, Decimal('91.4900'))
# ('Full-Finger Gloves, L', datetime.datetime(2007, 6, 30, 0, 0), Decimal('37.9900'))
# ('Full-Finger Gloves, M', datetime.datetime(2007, 6, 30, 0, 0), Decimal('37.9900'))
# ('Full-Finger Gloves, S', datetime.datetime(2007, 6, 30, 0, 0), Decimal('37.9900'))
# ('Half-Finger Gloves, L', None, Decimal('24.4900'))
# ('Half-Finger Gloves, L', datetime.datetime(2007, 6, 30, 0, 0), Decimal('23.5481'))
# ('Half-Finger Gloves, M', None, Decimal('24.4900'))
# ('Half-Finger Gloves, M', datetime.datetime(2007, 6, 30, 0, 0), Decimal('23.5481'))
# ('Half-Finger Gloves, S', None, Decimal('24.4900'))
# ('Half-Finger Gloves, S', datetime.datetime(2007, 6, 30, 0, 0), Decimal('23.5481'))
# ('Headlights - Dual-Beam', datetime.datetime(2007, 6, 30, 0, 0), Decimal('34.9900'))
# ('Headlights - Weatherproof', datetime.datetime(2007, 6, 30, 0, 0), Decimal('44.9900'))
# ('Hitch Rack - 4-Bike', None, Decimal('120.0000'))
# ('HL Bottom Bracket', None, Decimal('121.4900'))
# ('HL Crankset', None, Decimal('404.9900'))
# ('HL Fork', datetime.datetime(2007, 6, 30, 0, 0), Decimal('229.4900'))
# ('HL Headset', datetime.datetime(2007, 6, 30, 0, 0), Decimal('124.7300'))
# ('HL Mountain Frame - Black, 38', None, Decimal('1349.6000'))
# ('HL Mountain Frame - Black, 38', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1191.1739'))
# ('HL Mountain Frame - Black, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1226.9091'))
# ('HL Mountain Frame - Black, 42', None, Decimal('1349.6000'))
# ('HL Mountain Frame - Black, 42', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1191.1739'))
# ('HL Mountain Frame - Black, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1226.9091'))
# ('HL Mountain Frame - Black, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1349.6000'))
# ('HL Mountain Frame - Black, 46', None, Decimal('1349.6000'))
# ('HL Mountain Frame - Black, 46', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1191.1739'))
# ('HL Mountain Frame - Black, 46', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1226.9091'))
# ('HL Mountain Frame - Black, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1349.6000'))
# ('HL Mountain Frame - Silver, 38', None, Decimal('1364.5000'))
# ('HL Mountain Frame - Silver, 38', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1204.3248'))
# ('HL Mountain Frame - Silver, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1240.4545'))
# ('HL Mountain Frame - Silver, 42', None, Decimal('1364.5000'))
# ('HL Mountain Frame - Silver, 42', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1204.3248'))
# ('HL Mountain Frame - Silver, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1240.4545'))
# ('HL Mountain Frame - Silver, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1364.5000'))
# ('HL Mountain Frame - Silver, 46', None, Decimal('1364.5000'))
# ('HL Mountain Frame - Silver, 46', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1204.3248'))
# ('HL Mountain Frame - Silver, 46', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1240.4545'))
# ('HL Mountain Frame - Silver, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1364.5000'))
# ('HL Mountain Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('300.2150'))
# ('HL Mountain Handlebars', None, Decimal('120.2700'))
# ('HL Mountain Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('109.3364'))
# ('HL Mountain Pedal', None, Decimal('80.9900'))
# ('HL Mountain Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('327.2150'))
# ('HL Mountain Seat/Saddle', None, Decimal('52.6400'))
# ('HL Mountain Tire', None, Decimal('35.0000'))
# ('HL Road Frame - Black, 44', None, Decimal('1431.5000'))
# ('HL Road Frame - Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Black, 48', None, Decimal('1431.5000'))
# ('HL Road Frame - Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Black, 52', None, Decimal('1431.5000'))
# ('HL Road Frame - Black, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Black, 62', None, Decimal('1431.5000'))
# ('HL Road Frame - Black, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Red, 44', None, Decimal('1431.5000'))
# ('HL Road Frame - Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1263.4598'))
# ('HL Road Frame - Red, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Red, 48', None, Decimal('1431.5000'))
# ('HL Road Frame - Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1263.4598'))
# ('HL Road Frame - Red, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Red, 52', None, Decimal('1431.5000'))
# ('HL Road Frame - Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1263.4598'))
# ('HL Road Frame - Red, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Red, 56', None, Decimal('1431.5000'))
# ('HL Road Frame - Red, 56', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1263.4598'))
# ('HL Road Frame - Red, 56', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Frame - Red, 62', None, Decimal('1431.5000'))
# ('HL Road Frame - Red, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1263.4598'))
# ('HL Road Frame - Red, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1301.3636'))
# ('HL Road Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('330.0600'))
# ('HL Road Handlebars', None, Decimal('120.2700'))
# ('HL Road Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('109.3364'))
# ('HL Road Pedal', None, Decimal('80.9900'))
# ('HL Road Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('357.0600'))
# ('HL Road Seat/Saddle', None, Decimal('52.6400'))
# ('HL Road Tire', None, Decimal('32.6000'))
# ('HL Touring Frame - Blue, 46', None, Decimal('1003.9100'))
# ('HL Touring Frame - Blue, 50', None, Decimal('1003.9100'))
# ('HL Touring Frame - Blue, 54', None, Decimal('1003.9100'))
# ('HL Touring Frame - Blue, 60', None, Decimal('1003.9100'))
# ('HL Touring Frame - Yellow, 46', None, Decimal('1003.9100'))
# ('HL Touring Frame - Yellow, 50', None, Decimal('1003.9100'))
# ('HL Touring Frame - Yellow, 54', None, Decimal('1003.9100'))
# ('HL Touring Frame - Yellow, 60', None, Decimal('1003.9100'))
# ('HL Touring Handlebars', None, Decimal('91.5700'))
# ('HL Touring Seat/Saddle', None, Decimal('52.6400'))
# ('Hydration Pack - 70 oz.', None, Decimal('54.9900'))
# ('LL Bottom Bracket', None, Decimal('53.9900'))
# ('LL Crankset', None, Decimal('175.4900'))
# ('LL Fork', datetime.datetime(2007, 6, 30, 0, 0), Decimal('148.2200'))
# ('LL Headset', datetime.datetime(2007, 6, 30, 0, 0), Decimal('34.2000'))
# ('LL Mountain Frame - Black, 40', None, Decimal('249.7900'))
# ('LL Mountain Frame - Black, 42', None, Decimal('249.7900'))
# ('LL Mountain Frame - Black, 44', None, Decimal('249.7900'))
# ('LL Mountain Frame - Black, 48', None, Decimal('249.7900'))
# ('LL Mountain Frame - Black, 52', None, Decimal('249.7900'))
# ('LL Mountain Frame - Silver, 40', None, Decimal('264.0500'))
# ('LL Mountain Frame - Silver, 42', None, Decimal('264.0500'))
# ('LL Mountain Frame - Silver, 44', None, Decimal('264.0500'))
# ('LL Mountain Frame - Silver, 48', None, Decimal('264.0500'))
# ('LL Mountain Frame - Silver, 52', None, Decimal('264.0500'))
# ('LL Mountain Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('60.7450'))
# ('LL Mountain Handlebars', None, Decimal('44.5400'))
# ('LL Mountain Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('40.4909'))
# ('LL Mountain Pedal', None, Decimal('40.4900'))
# ('LL Mountain Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('87.7450'))
# ('LL Mountain Seat/Saddle', None, Decimal('27.1200'))
# ('LL Mountain Tire', None, Decimal('24.9900'))
# ('LL Road Frame - Black, 44', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Black, 48', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Black, 52', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Black, 58', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Black, 60', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 60', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Black, 62', None, Decimal('337.2200'))
# ('LL Road Frame - Black, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('297.6346'))
# ('LL Road Frame - Black, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Frame - Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Frame - Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Frame - Red, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Frame - Red, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 60', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Frame - Red, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('306.5636'))
# ('LL Road Frame - Red, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('337.2200'))
# ('LL Road Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('85.5650'))
# ('LL Road Handlebars', None, Decimal('44.5400'))
# ('LL Road Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('40.4909'))
# ('LL Road Pedal', None, Decimal('40.4900'))
# ('LL Road Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('112.5650'))
# ('LL Road Seat/Saddle', None, Decimal('27.1200'))
# ('LL Road Tire', None, Decimal('21.4900'))
# ('LL Touring Frame - Blue, 44', None, Decimal('333.4200'))
# ('LL Touring Frame - Blue, 50', None, Decimal('333.4200'))
# ('LL Touring Frame - Blue, 54', None, Decimal('333.4200'))
# ('LL Touring Frame - Blue, 58', None, Decimal('333.4200'))
# ('LL Touring Frame - Blue, 62', None, Decimal('333.4200'))
# ('LL Touring Frame - Yellow, 44', None, Decimal('333.4200'))
# ('LL Touring Frame - Yellow, 50', None, Decimal('333.4200'))
# ('LL Touring Frame - Yellow, 54', None, Decimal('333.4200'))
# ('LL Touring Frame - Yellow, 58', None, Decimal('333.4200'))
# ('LL Touring Frame - Yellow, 62', None, Decimal('333.4200'))
# ('LL Touring Handlebars', None, Decimal('46.0900'))
# ('LL Touring Seat/Saddle', None, Decimal('27.1200'))
# ('Long-Sleeve Logo Jersey, L', None, Decimal('49.9900'))
# ('Long-Sleeve Logo Jersey, L', datetime.datetime(2006, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, L', datetime.datetime(2007, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, M', None, Decimal('49.9900'))
# ('Long-Sleeve Logo Jersey, M', datetime.datetime(2006, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, M', datetime.datetime(2007, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, S', None, Decimal('49.9900'))
# ('Long-Sleeve Logo Jersey, S', datetime.datetime(2006, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, S', datetime.datetime(2007, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, XL', None, Decimal('49.9900'))
# ('Long-Sleeve Logo Jersey, XL', datetime.datetime(2006, 6, 30, 0, 0), Decimal('48.0673'))
# ('Long-Sleeve Logo Jersey, XL', datetime.datetime(2007, 6, 30, 0, 0), Decimal('48.0673'))
# ("Men's Bib-Shorts, L", datetime.datetime(2007, 6, 30, 0, 0), Decimal('89.9900'))
# ("Men's Bib-Shorts, M", datetime.datetime(2007, 6, 30, 0, 0), Decimal('89.9900'))
# ("Men's Bib-Shorts, S", datetime.datetime(2007, 6, 30, 0, 0), Decimal('89.9900'))
# ("Men's Sports Shorts, L", datetime.datetime(2007, 6, 30, 0, 0), Decimal('59.9900'))
# ("Men's Sports Shorts, M", datetime.datetime(2007, 6, 30, 0, 0), Decimal('59.9900'))
# ("Men's Sports Shorts, S", datetime.datetime(2007, 6, 30, 0, 0), Decimal('59.9900'))
# ("Men's Sports Shorts, XL", datetime.datetime(2007, 6, 30, 0, 0), Decimal('59.9900'))
# ('Minipump', datetime.datetime(2007, 6, 30, 0, 0), Decimal('19.9900'))
# ('ML Bottom Bracket', None, Decimal('101.2400'))
# ('ML Crankset', None, Decimal('256.4900'))
# ('ML Fork', datetime.datetime(2007, 6, 30, 0, 0), Decimal('175.4900'))
# ('ML Headset', datetime.datetime(2007, 6, 30, 0, 0), Decimal('102.2900'))
# ('ML Mountain Frame - Black, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('348.7600'))
# ('ML Mountain Frame - Black, 40', datetime.datetime(2007, 6, 30, 0, 0), Decimal('348.7600'))
# ('ML Mountain Frame - Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('348.7600'))
# ('ML Mountain Frame - Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('348.7600'))
# ('ML Mountain Frame-W - Silver, 38', None, Decimal('364.0900'))
# ('ML Mountain Frame-W - Silver, 40', None, Decimal('364.0900'))
# ('ML Mountain Frame-W - Silver, 42', None, Decimal('364.0900'))
# ('ML Mountain Frame-W - Silver, 46', None, Decimal('364.0900'))
# ('ML Mountain Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('209.0250'))
# ('ML Mountain Handlebars', None, Decimal('61.9200'))
# ('ML Mountain Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('56.2909'))
# ('ML Mountain Pedal', None, Decimal('62.0900'))
# ('ML Mountain Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('236.0250'))
# ('ML Mountain Seat/Saddle', None, Decimal('39.1400'))
# ('ML Mountain Tire', None, Decimal('29.9900'))
# ('ML Road Frame - Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('594.8300'))
# ('ML Road Frame - Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('594.8300'))
# ('ML Road Frame - Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('594.8300'))
# ('ML Road Frame - Red, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('594.8300'))
# ('ML Road Frame - Red, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 38', None, Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('540.7545'))
# ('ML Road Frame-W - Yellow, 40', None, Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 40', datetime.datetime(2007, 6, 30, 0, 0), Decimal('540.7545'))
# ('ML Road Frame-W - Yellow, 42', None, Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('540.7545'))
# ('ML Road Frame-W - Yellow, 44', None, Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('540.7545'))
# ('ML Road Frame-W - Yellow, 48', None, Decimal('594.8300'))
# ('ML Road Frame-W - Yellow, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('540.7545'))
# ('ML Road Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('248.3850'))
# ('ML Road Handlebars', None, Decimal('61.9200'))
# ('ML Road Handlebars', datetime.datetime(2007, 6, 30, 0, 0), Decimal('56.2909'))
# ('ML Road Pedal', None, Decimal('62.0900'))
# ('ML Road Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('275.3850'))
# ('ML Road Seat/Saddle', None, Decimal('39.1400'))
# ('ML Road Tire', None, Decimal('24.9900'))
# ('ML Touring Seat/Saddle', None, Decimal('39.1400'))
# ('Mountain Bike Socks, L', datetime.datetime(2006, 6, 30, 0, 0), Decimal('9.5000'))
# ('Mountain Bike Socks, M', datetime.datetime(2006, 6, 30, 0, 0), Decimal('9.5000'))
# ('Mountain Bottle Cage', None, Decimal('9.9900'))
# ('Mountain Pump', datetime.datetime(2007, 6, 30, 0, 0), Decimal('24.9900'))
# ('Mountain Tire Tube', None, Decimal('4.9900'))
# ('Mountain-100 Black, 38', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3374.9900'))
# ('Mountain-100 Black, 42', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3374.9900'))
# ('Mountain-100 Black, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3374.9900'))
# ('Mountain-100 Black, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3374.9900'))
# ('Mountain-100 Silver, 38', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3399.9900'))
# ('Mountain-100 Silver, 42', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3399.9900'))
# ('Mountain-100 Silver, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3399.9900'))
# ('Mountain-100 Silver, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3399.9900'))
# ('Mountain-200 Black, 38', None, Decimal('2294.9900'))
# ('Mountain-200 Black, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2049.0982'))
# ('Mountain-200 Black, 42', None, Decimal('2294.9900'))
# ('Mountain-200 Black, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2049.0982'))
# ('Mountain-200 Black, 46', None, Decimal('2294.9900'))
# ('Mountain-200 Black, 46', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2049.0982'))
# ('Mountain-200 Silver, 38', None, Decimal('2319.9900'))
# ('Mountain-200 Silver, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2071.4196'))
# ('Mountain-200 Silver, 42', None, Decimal('2319.9900'))
# ('Mountain-200 Silver, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2071.4196'))
# ('Mountain-200 Silver, 46', None, Decimal('2319.9900'))
# ('Mountain-200 Silver, 46', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2071.4196'))
# ('Mountain-300 Black, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1079.9900'))
# ('Mountain-300 Black, 40', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1079.9900'))
# ('Mountain-300 Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1079.9900'))
# ('Mountain-300 Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1079.9900'))
# ('Mountain-400-W Silver, 38', None, Decimal('769.4900'))
# ('Mountain-400-W Silver, 40', None, Decimal('769.4900'))
# ('Mountain-400-W Silver, 42', None, Decimal('769.4900'))
# ('Mountain-400-W Silver, 46', None, Decimal('769.4900'))
# ('Mountain-500 Black, 40', None, Decimal('539.9900'))
# ('Mountain-500 Black, 42', None, Decimal('539.9900'))
# ('Mountain-500 Black, 44', None, Decimal('539.9900'))
# ('Mountain-500 Black, 48', None, Decimal('539.9900'))
# ('Mountain-500 Black, 52', None, Decimal('539.9900'))
# ('Mountain-500 Silver, 40', None, Decimal('564.9900'))
# ('Mountain-500 Silver, 42', None, Decimal('564.9900'))
# ('Mountain-500 Silver, 44', None, Decimal('564.9900'))
# ('Mountain-500 Silver, 48', None, Decimal('564.9900'))
# ('Mountain-500 Silver, 52', None, Decimal('564.9900'))
# ('Patch Kit/8 Patches', None, Decimal('2.2900'))
# ('Racing Socks, L', None, Decimal('8.9900'))
# ('Racing Socks, M', None, Decimal('8.9900'))
# ('Rear Brakes', None, Decimal('106.5000'))
# ('Rear Derailleur', None, Decimal('121.4600'))
# ('Road Bottle Cage', None, Decimal('8.9900'))
# ('Road Tire Tube', None, Decimal('3.9900'))
# ('Road-150 Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3578.2700'))
# ('Road-150 Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3578.2700'))
# ('Road-150 Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3578.2700'))
# ('Road-150 Red, 56', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3578.2700'))
# ('Road-150 Red, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('3578.2700'))
# ('Road-250 Black, 44', None, Decimal('2443.3500'))
# ('Road-250 Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2181.5625'))
# ('Road-250 Black, 48', None, Decimal('2443.3500'))
# ('Road-250 Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2181.5625'))
# ('Road-250 Black, 52', None, Decimal('2443.3500'))
# ('Road-250 Black, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2181.5625'))
# ('Road-250 Black, 58', None, Decimal('2443.3500'))
# ('Road-250 Black, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2181.5625'))
# ('Road-250 Red, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2443.3500'))
# ('Road-250 Red, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2443.3500'))
# ('Road-250 Red, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2443.3500'))
# ('Road-250 Red, 58', None, Decimal('2443.3500'))
# ('Road-250 Red, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('2181.5625'))
# ('Road-350-W Yellow, 40', None, Decimal('1700.9900'))
# ('Road-350-W Yellow, 42', None, Decimal('1700.9900'))
# ('Road-350-W Yellow, 44', None, Decimal('1700.9900'))
# ('Road-350-W Yellow, 48', None, Decimal('1700.9900'))
# ('Road-450 Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1457.9900'))
# ('Road-450 Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1457.9900'))
# ('Road-450 Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1457.9900'))
# ('Road-450 Red, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1457.9900'))
# ('Road-450 Red, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('1457.9900'))
# ('Road-550-W Yellow, 38', None, Decimal('1120.4900'))
# ('Road-550-W Yellow, 38', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1000.4375'))
# ('Road-550-W Yellow, 40', None, Decimal('1120.4900'))
# ('Road-550-W Yellow, 40', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1000.4375'))
# ('Road-550-W Yellow, 42', None, Decimal('1120.4900'))
# ('Road-550-W Yellow, 42', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1000.4375'))
# ('Road-550-W Yellow, 44', None, Decimal('1120.4900'))
# ('Road-550-W Yellow, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1000.4375'))
# ('Road-550-W Yellow, 48', None, Decimal('1120.4900'))
# ('Road-550-W Yellow, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('1000.4375'))
# ('Road-650 Black, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Black, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Black, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Black, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Black, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 60', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Black, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Black, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 44', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 44', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 48', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 48', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 52', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 52', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 58', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 58', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 60', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 60', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-650 Red, 62', datetime.datetime(2006, 6, 30, 0, 0), Decimal('699.0982'))
# ('Road-650 Red, 62', datetime.datetime(2007, 6, 30, 0, 0), Decimal('782.9900'))
# ('Road-750 Black, 44', None, Decimal('539.9900'))
# ('Road-750 Black, 48', None, Decimal('539.9900'))
# ('Road-750 Black, 52', None, Decimal('539.9900'))
# ('Road-750 Black, 58', None, Decimal('539.9900'))
# ('Short-Sleeve Classic Jersey, L', None, Decimal('53.9900'))
# ('Short-Sleeve Classic Jersey, M', None, Decimal('53.9900'))
# ('Short-Sleeve Classic Jersey, S', None, Decimal('53.9900'))
# ('Short-Sleeve Classic Jersey, XL', None, Decimal('53.9900'))
# ('Sport-100 Helmet, Black', None, Decimal('34.9900'))
# ('Sport-100 Helmet, Black', datetime.datetime(2006, 6, 30, 0, 0), Decimal('33.6442'))
# ('Sport-100 Helmet, Black', datetime.datetime(2007, 6, 30, 0, 0), Decimal('33.6442'))
# ('Sport-100 Helmet, Blue', None, Decimal('34.9900'))
# ('Sport-100 Helmet, Blue', datetime.datetime(2006, 6, 30, 0, 0), Decimal('33.6442'))
# ('Sport-100 Helmet, Blue', datetime.datetime(2007, 6, 30, 0, 0), Decimal('33.6442'))
# ('Sport-100 Helmet, Red', None, Decimal('34.9900'))
# ('Sport-100 Helmet, Red', datetime.datetime(2006, 6, 30, 0, 0), Decimal('33.6442'))
# ('Sport-100 Helmet, Red', datetime.datetime(2007, 6, 30, 0, 0), Decimal('33.6442'))
# ('Taillights - Battery-Powered', datetime.datetime(2007, 6, 30, 0, 0), Decimal('13.9900'))
# ('Touring Front Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('218.0100'))
# ('Touring Pedal', None, Decimal('80.9900'))
# ('Touring Rear Wheel', datetime.datetime(2007, 6, 30, 0, 0), Decimal('245.0100'))
# ('Touring Tire', None, Decimal('28.9900'))
# ('Touring Tire Tube', None, Decimal('4.9900'))
# ('Touring-1000 Blue, 46', None, Decimal('2384.0700'))
# ('Touring-1000 Blue, 50', None, Decimal('2384.0700'))
# ('Touring-1000 Blue, 54', None, Decimal('2384.0700'))
# ('Touring-1000 Blue, 60', None, Decimal('2384.0700'))
# ('Touring-1000 Yellow, 46', None, Decimal('2384.0700'))
# ('Touring-1000 Yellow, 50', None, Decimal('2384.0700'))
# ('Touring-1000 Yellow, 54', None, Decimal('2384.0700'))
# ('Touring-1000 Yellow, 60', None, Decimal('2384.0700'))
# ('Touring-2000 Blue, 46', None, Decimal('1214.8500'))
# ('Touring-2000 Blue, 50', None, Decimal('1214.8500'))
# ('Touring-2000 Blue, 54', None, Decimal('1214.8500'))
# ('Touring-2000 Blue, 60', None, Decimal('1214.8500'))
# ('Touring-3000 Blue, 44', None, Decimal('742.3500'))
# ('Touring-3000 Blue, 50', None, Decimal('742.3500'))
# ('Touring-3000 Blue, 54', None, Decimal('742.3500'))
# ('Touring-3000 Blue, 58', None, Decimal('742.3500'))
# ('Touring-3000 Blue, 62', None, Decimal('742.3500'))
# ('Touring-3000 Yellow, 44', None, Decimal('742.3500'))
# ('Touring-3000 Yellow, 50', None, Decimal('742.3500'))
# ('Touring-3000 Yellow, 54', None, Decimal('742.3500'))
# ('Touring-3000 Yellow, 58', None, Decimal('742.3500'))
# ('Touring-3000 Yellow, 62', None, Decimal('742.3500'))
# ('Touring-Panniers, Large', datetime.datetime(2007, 6, 30, 0, 0), Decimal('125.0000'))
# ('Water Bottle - 30 oz.', None, Decimal('4.9900'))
# ("Women's Mountain Shorts, L", None, Decimal('69.9900'))
# ("Women's Mountain Shorts, M", None, Decimal('69.9900'))
# ("Women's Mountain Shorts, S", None, Decimal('69.9900'))
# ("Women's Tights, L", datetime.datetime(2007, 6, 30, 0, 0), Decimal('74.9900'))
# ("Women's Tights, M", datetime.datetime(2007, 6, 30, 0, 0), Decimal('74.9900'))
# ("Women's Tights, S", datetime.datetime(2007, 6, 30, 0, 0), Decimal('74.9900'))

# %%
# Question 2 - AdventureWorks DB - Person & PersonPhone table
# 2. Get phone numbers for all Persons who’s first name is Kim (join Person & PersonPhone)

# SELECT FULLNAME using FullName (Person.LastName, Person.FirstName), Phone.PhoneNumber
# JOIN [AdventureWorks2012].[Person].[Person] AS Person & [AdventureWorks2012].[Person].[PersonPhone] AS Phone table
# ON BusinessEntityID
# WHERE Person.FirstName = 'Kim'

# Create the Cursor.
cursor = conn.cursor()

# Performing a join to combine ProductListPriceHistory & Product table
cursor.execute("""SELECT Person.LastName + ', ' + Person.FirstName AS [Full Name], Phone.PhoneNumber
                  FROM [AdventureWorks2012].[Person].[Person] AS Person
                  JOIN [AdventureWorks2012].[Person].[PersonPhone] AS Phone 
                  ON Person.BusinessEntityID = Phone.BusinessEntityID
                  WHERE Person.FirstName = 'Kim'""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['Full Name', 'PhoneNumber']
# ('Abercrombie, Kim', '334-555-0137')
# ('Abercrombie, Kim', '919-555-0100')
# ('Abercrombie, Kim', '208-555-0114')
# ('Akers, Kim', '440-555-0166')
# ('Akers, Kim', '791-555-0100')
# ('Akers, Kim', '508-555-0100')
# ('Ralls, Kim', '193-555-0100')
# ('Ralls, Kim', '197-555-0100')
# ('Ralls, Kim', '133-555-0100')
# ('Ralls, Kim', '309-555-0129')

# %%
# Question 3 - AdventureWorks DB - BusinessEntityAddress,AddressType, Address, StateProvince
# 3. Get the Address Type, City, and State Code for Business entity 332 (Join
# [BusinessEntityAddress], [AddressType], Address, StateProvince)

# SELECT  AddressType, City, and State Code
# JOIN [AdventureWorks2012].[Person].[BusinessEntityAddress] AS Entity
# [AdventureWorks2012].[Person].[AddressType] AS Type
# ON AddressTypeID
# [AdventureWorks2012].[Person].[Address] AS Address
# ON AddressID
# [AdventureWorks2012].[Person].[StateProvince] AS State
# ON StateProvinceID
# WHERE Business entity 332

# Create the Cursor.
cursor = conn.cursor()

# Performing a join to combine ProductListPriceHistory & Product table
cursor.execute("""SELECT Entity.BusinessEntityID, Type.Name, Address.City, State.StateProvinceCode AS State
                  FROM [AdventureWorks2012].[Person].[AddressType] AS Type
                  INNER JOIN [AdventureWorks2012].[Person].[BusinessEntityAddress] AS Entity
                  ON Type.AddressTypeID = Entity.AddressTypeID
                  INNER JOIN [AdventureWorks2012].[Person].[Address] AS Address
                  ON Entity.AddressID = Address.AddressID
                  INNER JOIN [AdventureWorks2012].[Person].[StateProvince] AS State
                  ON State.StateProvinceID = Address.StateProvinceID
                  WHERE Entity.BusinessEntityID = 332""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['BusinessEntityID', 'Name', 'City', 'State']
# (332, 'Shipping', 'Montreal', 'QC ')
# (332, 'Main Office', 'Montreal', 'QC ')

# %%
# Question 4 - AdventureWorks DB - WorkOrder & ScrapReason
# 4. Count the Work orders by scrape reason (ScrapReason.name). Disregard
# scrap reasons with less than 50 work orders (Join ScrapReason &
# WorkOrder on ScrapReasonID)

# SELECT ScrapeReason.Name, COUNT(WorkOrder.WorkOrderID)
# JOIN [AdventureWorks2012].[Production].[WorkOrder] AS WorkOrder
# [AdventureWorks2012].[Production].[ScrapReason] AS ScrapReason
# ON ScrapeReasonID
# GROUP BY ScrapReasonID
# HAVING COUNT(WorkOrder.WorkOrderID) >= 50

# Create the Cursor.
cursor = conn.cursor()

# Performing a join to combine ScrapReason & WorkOrder table
cursor.execute("""SELECT ScrapReason.Name AS [Scrap Reason], COUNT(WorkOrder.WorkOrderID) AS [Amount Discarded]
                  FROM [AdventureWorks2012].[Production].[WorkOrder] AS WorkOrder
                  INNER JOIN [AdventureWorks2012].[Production].[ScrapReason] AS ScrapReason
                  ON WorkOrder.ScrapReasonID = ScrapReason.ScrapReasonID
                  GROUP BY ScrapReason.Name
                  HAVING COUNT(WorkOrder.WorkOrderID) >= 50
                  ORDER BY COUNT(WorkOrder.WorkOrderID) DESC""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['Scrap Reason', 'Amount Discarded']
# ('Thermoform temperature too low', 63)
# ('Gouge in metal', 54)
# ('Stress test failed', 52)
# ('Trim length too long', 52)
# ('Wheel misaligned', 51)

# %%
# Question 5 - AdventureWorks DB - AddressType & ContactType table

# 5. Write a query that generates 3 copies out of each [AddressType] row
# (Hint: Cross Join to any table that has 3 records)

# Create the Cursor.
cursor = conn.cursor()

# Performing a cross join to combine AddressType & ContactType table
cursor.execute("""SELECT AddressType.*
                  FROM [AdventureWorks2012].[Person].[AddressType]  AS AddressType
                  CROSS JOIN [AdventureWorks2012].[Person].[ContactType] AS ContactType
                  WHERE ContactType.ContactTypeID <= 3
                  ORDER BY 1""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['AddressTypeID', 'Name', 'rowguid', 'ModifiedDate']
# (1, 'Billing', 'B84F78B1-4EFE-4A0E-8CB7-70E9F112F886', datetime.datetime(2002, 6, 1, 0, 0))
# (1, 'Billing', 'B84F78B1-4EFE-4A0E-8CB7-70E9F112F886', datetime.datetime(2002, 6, 1, 0, 0))
# (1, 'Billing', 'B84F78B1-4EFE-4A0E-8CB7-70E9F112F886', datetime.datetime(2002, 6, 1, 0, 0))
# (2, 'Home', '41BC2FF6-F0FC-475F-8EB9-CEC0805AA0F2', datetime.datetime(2002, 6, 1, 0, 0))
# (2, 'Home', '41BC2FF6-F0FC-475F-8EB9-CEC0805AA0F2', datetime.datetime(2002, 6, 1, 0, 0))
# (2, 'Home', '41BC2FF6-F0FC-475F-8EB9-CEC0805AA0F2', datetime.datetime(2002, 6, 1, 0, 0))
# (3, 'Main Office', '8EEEC28C-07A2-4FB9-AD0A-42D4A0BBC575', datetime.datetime(2002, 6, 1, 0, 0))
# (3, 'Main Office', '8EEEC28C-07A2-4FB9-AD0A-42D4A0BBC575', datetime.datetime(2002, 6, 1, 0, 0))
# (3, 'Main Office', '8EEEC28C-07A2-4FB9-AD0A-42D4A0BBC575', datetime.datetime(2002, 6, 1, 0, 0))
# (4, 'Primary', '24CB3088-4345-47C4-86C5-17B535133D1E', datetime.datetime(2002, 6, 1, 0, 0))
# (4, 'Primary', '24CB3088-4345-47C4-86C5-17B535133D1E', datetime.datetime(2002, 6, 1, 0, 0))
# (4, 'Primary', '24CB3088-4345-47C4-86C5-17B535133D1E', datetime.datetime(2002, 6, 1, 0, 0))
# (5, 'Shipping', 'B29DA3F8-19A3-47DA-9DAA-15C84F4A83A5', datetime.datetime(2002, 6, 1, 0, 0))
# (5, 'Shipping', 'B29DA3F8-19A3-47DA-9DAA-15C84F4A83A5', datetime.datetime(2002, 6, 1, 0, 0))
# (5, 'Shipping', 'B29DA3F8-19A3-47DA-9DAA-15C84F4A83A5', datetime.datetime(2002, 6, 1, 0, 0))
# (6, 'Archive', 'A67F238A-5BA2-444B-966C-0467ED9C427F', datetime.datetime(2002, 6, 1, 0, 0))
# (6, 'Archive', 'A67F238A-5BA2-444B-966C-0467ED9C427F', datetime.datetime(2002, 6, 1, 0, 0))
# (6, 'Archive', 'A67F238A-5BA2-444B-966C-0467ED9C427F', datetime.datetime(2002, 6, 1, 0, 0))

# %%
# Question 6 - AdventureWorks DB - SalesOrderHeader & Customer table

# 6. Return customer IDs, their order IDs, and the order DT including
# customers who placed no orders. Only include account #s which start
# with AW0002981

# SELECT Customer.CustomerID, Header.OrderDate, Header.SalesOrderID, Customer.AccountNumber
# JOIN FROM [AdventureWorks2012].[Sales].[SalesOrderHeader] AS Header
# [AdventureWorks2012].[Sales].[Customer] AS Customer
# ON CustomerID
# WHERE Customer.AccountNumber LIKE 'AW0002981%'
# GROUP BY Customer.CustomerID

# Create the Cursor.
cursor = conn.cursor()

# Performing a cross left join to combine Customer & SalesOrderHeader table
cursor.execute("""SELECT Customer.CustomerID, Header.OrderDate, Header.SalesOrderID, Customer.AccountNumber
                  FROM [AdventureWorks2012].[Sales].[SalesOrderHeader] AS Header
                  LEFT JOIN [AdventureWorks2012].[Sales].[Customer] AS Customer
                  ON Header.CustomerID = Customer.CustomerID
                  WHERE Customer.AccountNumber LIKE 'AW0002981%'
                  ORDER BY Customer.CustomerID""")

# Using a for loop to print a of the column headers for table
column_headers = [i[0] for i in cursor.description]
print(column_headers)

sql_query = cursor.fetchall()
for row in sql_query:
    print(row)
    
print("\n")

# close the cursor
# cursor.close()
# conn.close()
# Out:
# ['CustomerID', 'OrderDate', 'SalesOrderID', 'AccountNumber']
# (29810, datetime.datetime(2005, 9, 1, 0, 0), 44126, 'AW00029810')
# (29810, datetime.datetime(2005, 12, 1, 0, 0), 44792, 'AW00029810')
# (29810, datetime.datetime(2006, 3, 1, 0, 0), 45570, 'AW00029810')
# (29810, datetime.datetime(2006, 6, 1, 0, 0), 46379, 'AW00029810')
# (29810, datetime.datetime(2006, 9, 1, 0, 0), 47443, 'AW00029810')
# (29810, datetime.datetime(2006, 12, 1, 0, 0), 48381, 'AW00029810')
# (29810, datetime.datetime(2007, 3, 1, 0, 0), 49539, 'AW00029810')
# (29810, datetime.datetime(2007, 6, 1, 0, 0), 50750, 'AW00029810')
# (29810, datetime.datetime(2007, 9, 1, 0, 0), 53584, 'AW00029810')
# (29810, datetime.datetime(2007, 12, 1, 0, 0), 59019, 'AW00029810')
# (29810, datetime.datetime(2008, 3, 1, 0, 0), 65270, 'AW00029810')
# (29810, datetime.datetime(2008, 6, 1, 0, 0), 71932, 'AW00029810')
# (29811, datetime.datetime(2005, 7, 1, 0, 0), 43676, 'AW00029811')
# (29811, datetime.datetime(2005, 10, 1, 0, 0), 44297, 'AW00029811')
# (29811, datetime.datetime(2006, 1, 1, 0, 0), 45056, 'AW00029811')
# (29811, datetime.datetime(2006, 4, 1, 0, 0), 45796, 'AW00029811')
# (29811, datetime.datetime(2006, 7, 1, 0, 0), 46631, 'AW00029811')
# (29811, datetime.datetime(2006, 10, 1, 0, 0), 47684, 'AW00029811')
# (29811, datetime.datetime(2007, 1, 1, 0, 0), 48759, 'AW00029811')
# (29811, datetime.datetime(2007, 4, 1, 0, 0), 49868, 'AW00029811')
# (29811, datetime.datetime(2007, 7, 1, 0, 0), 51110, 'AW00029811')
# (29811, datetime.datetime(2007, 10, 1, 0, 0), 55260, 'AW00029811')
# (29811, datetime.datetime(2008, 1, 1, 0, 0), 61223, 'AW00029811')
# (29811, datetime.datetime(2008, 4, 1, 0, 0), 67283, 'AW00029811')
# (29812, datetime.datetime(2007, 9, 1, 0, 0), 53608, 'AW00029812')
# (29812, datetime.datetime(2007, 9, 1, 0, 0), 53609, 'AW00029812')
# (29812, datetime.datetime(2007, 12, 1, 0, 0), 59033, 'AW00029812')
# (29812, datetime.datetime(2007, 12, 1, 0, 0), 59053, 'AW00029812')
# (29812, datetime.datetime(2008, 2, 29, 0, 0), 65090, 'AW00029812')
# (29812, datetime.datetime(2008, 3, 1, 0, 0), 65305, 'AW00029812')
# (29812, datetime.datetime(2008, 5, 31, 0, 0), 71692, 'AW00029812')
# (29812, datetime.datetime(2008, 6, 1, 0, 0), 71910, 'AW00029812')
# (29813, datetime.datetime(2005, 8, 1, 0, 0), 43853, 'AW00029813')
# (29813, datetime.datetime(2005, 11, 1, 0, 0), 44495, 'AW00029813')
# (29813, datetime.datetime(2006, 2, 1, 0, 0), 45276, 'AW00029813')
# (29813, datetime.datetime(2006, 5, 1, 0, 0), 46035, 'AW00029813')
# (29814, datetime.datetime(2007, 8, 1, 0, 0), 51874, 'AW00029814')
# (29814, datetime.datetime(2007, 11, 1, 0, 0), 57190, 'AW00029814')
# (29814, datetime.datetime(2008, 2, 1, 0, 0), 63220, 'AW00029814')
# (29814, datetime.datetime(2008, 5, 1, 0, 0), 69565, 'AW00029814')
# (29815, datetime.datetime(2006, 9, 1, 0, 0), 47436, 'AW00029815')
# (29815, datetime.datetime(2006, 12, 1, 0, 0), 48374, 'AW00029815')
# (29815, datetime.datetime(2007, 3, 1, 0, 0), 49534, 'AW00029815')
# (29815, datetime.datetime(2007, 6, 1, 0, 0), 50746, 'AW00029815')
# (29815, datetime.datetime(2007, 9, 1, 0, 0), 53607, 'AW00029815')
# (29815, datetime.datetime(2007, 12, 1, 0, 0), 59014, 'AW00029815')
# (29815, datetime.datetime(2008, 3, 1, 0, 0), 65307, 'AW00029815')
# (29815, datetime.datetime(2008, 6, 1, 0, 0), 71890, 'AW00029815')
# (29816, datetime.datetime(2006, 8, 1, 0, 0), 46976, 'AW00029816')
# (29816, datetime.datetime(2006, 11, 1, 0, 0), 47997, 'AW00029816')
# (29816, datetime.datetime(2007, 2, 1, 0, 0), 49054, 'AW00029816')
# (29816, datetime.datetime(2007, 5, 1, 0, 0), 50216, 'AW00029816')
# (29816, datetime.datetime(2007, 8, 1, 0, 0), 51728, 'AW00029816')
# (29816, datetime.datetime(2007, 11, 1, 0, 0), 57044, 'AW00029816')
# (29816, datetime.datetime(2008, 2, 1, 0, 0), 63198, 'AW00029816')
# (29816, datetime.datetime(2008, 5, 1, 0, 0), 69488, 'AW00029816')
# (29817, datetime.datetime(2007, 8, 1, 0, 0), 51775, 'AW00029817')
# (29817, datetime.datetime(2007, 11, 1, 0, 0), 57088, 'AW00029817')
# (29817, datetime.datetime(2008, 2, 1, 0, 0), 63181, 'AW00029817')
# (29817, datetime.datetime(2008, 5, 1, 0, 0), 69465, 'AW00029817')
# (29818, datetime.datetime(2005, 8, 1, 0, 0), 43849, 'AW00029818')
# (29818, datetime.datetime(2005, 11, 1, 0, 0), 44492, 'AW00029818')
# (29818, datetime.datetime(2006, 2, 1, 0, 0), 45274, 'AW00029818')
# (29818, datetime.datetime(2006, 5, 1, 0, 0), 46032, 'AW00029818')
# (29818, datetime.datetime(2006, 8, 1, 0, 0), 46944, 'AW00029818')
# (29818, datetime.datetime(2006, 11, 1, 0, 0), 47970, 'AW00029818')
# (29818, datetime.datetime(2007, 2, 1, 0, 0), 49095, 'AW00029818')
# (29818, datetime.datetime(2007, 5, 1, 0, 0), 50270, 'AW00029818')
# (29818, datetime.datetime(2007, 8, 1, 0, 0), 51783, 'AW00029818')
# (29818, datetime.datetime(2007, 11, 1, 0, 0), 57105, 'AW00029818')
# (29818, datetime.datetime(2008, 2, 1, 0, 0), 63131, 'AW00029818')
# (29818, datetime.datetime(2008, 5, 1, 0, 0), 69471, 'AW00029818')
# (29819, datetime.datetime(2006, 8, 1, 0, 0), 47064, 'AW00029819')
# (29819, datetime.datetime(2006, 11, 1, 0, 0), 48091, 'AW00029819')
# (29819, datetime.datetime(2007, 2, 1, 0, 0), 49168, 'AW00029819')
# (29819, datetime.datetime(2007, 5, 1, 0, 0), 50320, 'AW00029819')
# (29819, datetime.datetime(2007, 8, 1, 0, 0), 51873, 'AW00029819')
